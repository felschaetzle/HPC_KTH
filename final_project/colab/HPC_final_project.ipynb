# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import optimize
from functools import partial

"""
Create Your Own Artificial Neural Network for Multi-class Classification (With Python)
Philip Mocz (2023), @PMocz

Create and train your own artificial neural network to classify images of galaxies from SDSS/the Galaxy Zoo project.

"""
def g(x):
	""" sigmoid function """
	return 1.0 / (1.0 + np.exp(-x))

def grad_g(x):
	""" gradient of sigmoid function """
	gx = g(x)
	return gx * (1.0 - gx)

def predict(Theta1, Theta2, X):
	""" Predict labels in a trained three layer classification network.
	Input:
	  Theta1       trained weights applied to 1st layer (hidden_layer_size x input_layer_size+1)
	  Theta2       trained weights applied to 2nd layer (num_labels x hidden_layer_size+1)
	  X            matrix of training data      (m x input_layer_size)
	Output:
	  prediction   label prediction
	"""

	m = np.shape(X)[0]                    # number of training values
	num_labels = np.shape(Theta2)[0]

	a1 = np.hstack((np.ones((m,1)), X))   # add bias (input layer)
	a2 = g(a1 @ Theta1.T)                 # apply sigmoid: input layer --> hidden layer
	a2 = np.hstack((np.ones((m,1)), a2))  # add bias (hidden layer)
	a3 = g(a2 @ Theta2.T)                 # apply sigmoid: hidden layer --> output layer

	prediction = np.argmax(a3,1).reshape((m,1))
	return prediction


def reshape(theta, input_layer_size, hidden_layer_size, num_labels):
	""" reshape theta into Theta1 and Theta2, the weights of our neural network """
	ncut = hidden_layer_size * (input_layer_size+1)
	Theta1 = theta[0:ncut].reshape(hidden_layer_size, input_layer_size+1)
	Theta2 = theta[ncut:].reshape(num_labels, hidden_layer_size+1)
	return Theta1, Theta2


def cost_function(theta, input_layer_size, hidden_layer_size, num_labels, X, y, lmbda):
	""" Neural net cost function for a three layer classification network.
	Input:
	  theta               flattened vector of neural net model parameters
	  input_layer_size    size of input layer
	  hidden_layer_size   size of hidden layer
	  num_labels          number of labels
	  X                   matrix of training data
	  y                   vector of training labels
	  lmbda               regularization term
	Output:
	  J                   cost function
	"""

	# unflatten theta
	Theta1, Theta2 = reshape(theta, input_layer_size, hidden_layer_size, num_labels)

	# number of training values
	m = len(y)

	# Feedforward: calculate the cost function J:

	a1 = np.hstack((np.ones((m,1)), X))
	a2 = g(a1 @ Theta1.T)
	a2 = np.hstack((np.ones((m,1)), a2))
	a3 = g(a2 @ Theta2.T)

	y_mtx = 1.*(y==0)
	for k in range(1,num_labels):
		y_mtx = np.hstack((y_mtx, 1.*(y==k)))

	# cost function
	J = np.sum( -y_mtx * np.log(a3) - (1.0-y_mtx) * np.log(1.0-a3) ) / m

	# add regularization
	J += lmbda/(2.*m) * (np.sum(Theta1[:,1:]**2)  + np.sum(Theta2[:,1:]**2))

	return J


def gradient(theta, input_layer_size, hidden_layer_size, num_labels, X, y, lmbda):
	""" Neural net cost function gradient for a three layer classification network.
	Input:
	  theta               flattened vector of neural net model parameters
	  input_layer_size    size of input layer
	  hidden_layer_size   size of hidden layer
	  num_labels          number of labels
	  X                   matrix of training data
	  y                   vector of training labels
	  lmbda               regularization term
	Output:
	  grad                flattened vector of derivatives of the neural network
	"""

	# unflatten theta
	Theta1, Theta2 = reshape(theta, input_layer_size, hidden_layer_size, num_labels)

	# number of training values
	m = len(y)

	# Backpropagation: calculate the gradients Theta1_grad and Theta2_grad:

	Delta1 = np.zeros((hidden_layer_size,input_layer_size+1))
	Delta2 = np.zeros((num_labels,hidden_layer_size+1))

	for t in range(m):

		# forward
		a1 = X[t,:].reshape((input_layer_size,1))
		a1 = np.vstack((1, a1))   #  +bias
		z2 = Theta1 @ a1
		a2 = g(z2)
		a2 = np.vstack((1, a2))   #  +bias
		a3 = g(Theta2 @ a2)

		# compute error for layer 3
		y_k = np.zeros((num_labels,1))
		y_k[y[t,0].astype(int)] = 1
		delta3 = a3 - y_k
		Delta2 += (delta3 @ a2.T)

		# compute error for layer 2
		delta2 = (Theta2[:,1:].T @ delta3) * grad_g(z2)
		Delta1 += (delta2 @ a1.T)

	Theta1_grad = Delta1 / m
	Theta2_grad = Delta2 / m

	# add regularization
	Theta1_grad[:,1:] += (lmbda/m) * Theta1[:,1:]
	Theta2_grad[:,1:] += (lmbda/m) * Theta2[:,1:]

	# flatten gradients
	grad = np.concatenate((Theta1_grad.flatten(), Theta2_grad.flatten()))

	return grad


N_iter = 1
J_min = np.Inf
theta_best = []
Js_train = np.array([])
Js_test = np.array([])

def callbackF(input_layer_size, hidden_layer_size, num_labels, X, y, lmbda, test, test_label, theta_k):
	""" Calculate some stats per iteration and update plot """
	plot = False

	global N_iter
	global J_min
	global theta_best
	global Js_train
	global Js_test
	# unflatten theta
	Theta1, Theta2 = reshape(theta_k, input_layer_size, hidden_layer_size, num_labels)
	# training data stats
	J = cost_function(theta_k, input_layer_size, hidden_layer_size, num_labels, X, y, lmbda)
	y_pred = predict(Theta1, Theta2, X)
	accuracy = np.sum(1.*(y_pred==y))/len(y)
	Js_train = np.append(Js_train, J)
	# test data stats
	J_test = cost_function(theta_k, input_layer_size, hidden_layer_size, num_labels, test, test_label, lmbda)
	test_pred = predict(Theta1, Theta2, test)
	accuracy_test = np.sum(1.*(test_pred==test_label))/len(test_label)
	Js_test= np.append(Js_test, J_test)
	# print stats
	print('iter={:3d}:  Jtrain= {:0.4f} acc= {:0.2f}%  |  Jtest= {:0.4f} acc= {:0.2f}%'.format(N_iter, J, 100*accuracy, J_test, 100*accuracy_test))
	N_iter += 1
	# Update theta_best
	if (J_test < J_min):
		theta_best = theta_k
		J_min = J_test

	# Update Plot
	if(plot):
		iters = np.arange(len(Js_train))
		plt.clf()
		plt.subplot(2,1,1)
		im_size = 32
		pad = 4
		galaxies_image = np.zeros((3*im_size,6*im_size+2*pad), dtype=int) + 255
		for i in range(3):
			for j in range(6):
				idx = 3*j + i + 900*(j>1) + 900*(j>3) + (N_iter % 600) # +10
				shift = 0 + pad*(j>1) + pad*(j>3)
				ii = i * im_size
				jj = j * im_size + shift
				galaxies_image[ii:ii+im_size,jj:jj+im_size] = X[idx].reshape(im_size,im_size) * 255
				my_label = 'E' if y_pred[idx]==0 else 'S' if y_pred[idx]==1 else 'I'
				my_color = 'blue' if (y_pred[idx]==y[idx]) else 'red'
				plt.text(jj+2, ii+10, my_label, color=my_color)
				if (y_pred[idx]==y[idx]):
					plt.text(jj+4, ii+25, "✓", color='blue', fontsize=50)

		plt.imshow(galaxies_image, cmap='gray')
		plt.gca().axis('off')
		plt.subplot(2,1,2)
		plt.plot(iters, Js_test, 'r', label='test')
		plt.plot(iters, Js_train, 'b', label='train')
		plt.xlabel("iteration")
		plt.ylabel("cost")
		plt.xlim(0,600)
		plt.ylim(1,2.1)
		plt.gca().legend()
		plt.pause(0.001)


def main():
	""" Artificial Neural Network for classifying galaxies """

	# set the random number generator seed
	np.random.seed(917)

	# Load the training and test datasets
	train = np.genfromtxt('gdrive/MyDrive/train.csv', delimiter=',')
	test = np.genfromtxt('gdrive/MyDrive/test.csv', delimiter=',')

	# get labels (0=Elliptical, 1=Spiral, 2=Irregular)
	train_label = train[:,0].reshape(len(train),1)
	test_label = test[:,0].reshape(len(test),1)

	# normalize image data to [0,1]
	train = train[:,1:] / 255.
	test = test[:,1:] / 255.

	# Construct our data matrix X (2700 x 5000)
	X = train

    # Construct our label vector y (2700 x 1)
	y = train_label

	# Two layer Neural Network parameters:
	m = np.shape(X)[0]
	input_layer_size = np.shape(X)[1]
	hidden_layer_size = 8
	num_labels = 3
	lmbda = 1.0    # regularization parameter

	# Initialize random weights:
	Theta1 = np.random.rand(hidden_layer_size, input_layer_size+1) * 0.4 - 0.2
	Theta2 = np.random.rand(num_labels, hidden_layer_size+1) * 0.4 - 0.2

	# flattened initial guess
	theta0 = np.concatenate((Theta1.flatten(), Theta2.flatten()))
	J = cost_function(theta0, input_layer_size, hidden_layer_size, num_labels, X, y, lmbda)
	print('initial cost function J =', J)
	train_pred = predict(Theta1, Theta2, train)
	print('initial accuracy on training set =', np.sum(1.*(train_pred==train_label))/len(train_label))
	global Js_train
	global Js_test
	Js_train = np.array([J])
	J_test = cost_function(theta0, input_layer_size, hidden_layer_size, num_labels, test, test_label, lmbda)
	Js_test = np.array([J_test])

	# prep figure
	# fig = plt.figure(figsize=(6,6), dpi=80)

	# Minimize the cost function using a nonlinear conjugate gradient algorithm
	args = (input_layer_size, hidden_layer_size, num_labels, X, y, lmbda)  # parameter values
	cbf = partial(callbackF, input_layer_size, hidden_layer_size, num_labels, X, y, lmbda, test, test_label)
	theta = optimize.fmin_cg(cost_function, theta0, fprime=gradient, args=args, callback=cbf, maxiter=600)

	# unflatten theta
	Theta1, Theta2 = reshape(theta_best, input_layer_size, hidden_layer_size, num_labels)

	# Make predictions for the training and test sets
	train_pred = predict(Theta1, Theta2, train)
	test_pred = predict(Theta1, Theta2, test)

	# Print accuracy of predictions
	print('accuracy on training set =', np.sum(1.*(train_pred==train_label))/len(train_label))
	print('accuracy on test set =', np.sum(1.*(test_pred==test_label))/len(test_label))

	# Save figure
	# plt.savefig('artificialneuralnetwork.png',dpi=240)
	# plt.show()

	return 0

# %%
# %%time
main()
print("Colab CPU performance")
# Out:
# initial cost function J = 2.0368341799643392
# iter= 90:  Jtrain= 1.6859 acc= 58.33%  |  Jtest= 1.7262 acc= 59.70%
# iter= 91:  Jtrain= 1.6856 acc= 58.30%  |  Jtest= 1.7264 acc= 60.00%
# iter= 92:  Jtrain= 1.6849 acc= 58.33%  |  Jtest= 1.7258 acc= 58.67%
# iter= 93:  Jtrain= 1.6839 acc= 58.48%  |  Jtest= 1.7254 acc= 59.11%
# iter= 94:  Jtrain= 1.6837 acc= 58.48%  |  Jtest= 1.7256 acc= 59.56%
# iter= 95:  Jtrain= 1.6835 acc= 58.52%  |  Jtest= 1.7257 acc= 59.70%
# iter= 96:  Jtrain= 1.6811 acc= 58.96%  |  Jtest= 1.7249 acc= 59.11%
# iter= 97:  Jtrain= 1.6788 acc= 58.93%  |  Jtest= 1.7217 acc= 59.85%
# iter= 98:  Jtrain= 1.6786 acc= 59.26%  |  Jtest= 1.7213 acc= 59.85%
# iter= 99:  Jtrain= 1.6783 acc= 59.07%  |  Jtest= 1.7214 acc= 60.15%
# iter=100:  Jtrain= 1.6779 acc= 58.93%  |  Jtest= 1.7209 acc= 60.44%
# iter=101:  Jtrain= 1.6774 acc= 59.00%  |  Jtest= 1.7199 acc= 60.44%
# iter=102:  Jtrain= 1.6772 acc= 59.11%  |  Jtest= 1.7194 acc= 59.56%
# iter=103:  Jtrain= 1.6771 acc= 59.11%  |  Jtest= 1.7192 acc= 59.70%
# iter=104:  Jtrain= 1.6767 acc= 59.30%  |  Jtest= 1.7195 acc= 60.00%
# iter=105:  Jtrain= 1.6766 acc= 59.22%  |  Jtest= 1.7194 acc= 59.70%
# iter=106:  Jtrain= 1.6763 acc= 59.07%  |  Jtest= 1.7182 acc= 60.15%
# iter=107:  Jtrain= 1.6755 acc= 59.04%  |  Jtest= 1.7171 acc= 60.00%
# iter=108:  Jtrain= 1.6753 acc= 58.96%  |  Jtest= 1.7171 acc= 60.00%
# iter=109:  Jtrain= 1.6744 acc= 59.11%  |  Jtest= 1.7165 acc= 60.00%
# iter=110:  Jtrain= 1.6741 acc= 59.22%  |  Jtest= 1.7163 acc= 60.44%
# iter=111:  Jtrain= 1.6738 acc= 59.11%  |  Jtest= 1.7166 acc= 60.44%
# iter=112:  Jtrain= 1.6737 acc= 59.22%  |  Jtest= 1.7166 acc= 60.30%
# iter=113:  Jtrain= 1.6736 acc= 59.19%  |  Jtest= 1.7163 acc= 59.85%
# iter=114:  Jtrain= 1.6735 acc= 59.33%  |  Jtest= 1.7162 acc= 60.30%
# iter=115:  Jtrain= 1.6720 acc= 59.15%  |  Jtest= 1.7165 acc= 60.30%
# iter=116:  Jtrain= 1.6703 acc= 59.37%  |  Jtest= 1.7157 acc= 60.00%
# iter=117:  Jtrain= 1.6585 acc= 60.26%  |  Jtest= 1.7032 acc= 61.19%
# iter=118:  Jtrain= 1.6526 acc= 59.52%  |  Jtest= 1.6989 acc= 60.89%
# iter=119:  Jtrain= 1.6488 acc= 59.11%  |  Jtest= 1.6978 acc= 61.33%
# iter=120:  Jtrain= 1.5847 acc= 61.70%  |  Jtest= 1.6488 acc= 63.56%
# iter=121:  Jtrain= 1.5834 acc= 61.93%  |  Jtest= 1.6475 acc= 63.41%
# iter=122:  Jtrain= 1.5816 acc= 62.11%  |  Jtest= 1.6442 acc= 63.70%
# iter=123:  Jtrain= 1.5797 acc= 61.78%  |  Jtest= 1.6425 acc= 64.15%
# iter=124:  Jtrain= 1.5780 acc= 61.74%  |  Jtest= 1.6397 acc= 63.56%
# iter=125:  Jtrain= 1.5735 acc= 61.85%  |  Jtest= 1.6336 acc= 65.04%
# iter=126:  Jtrain= 1.5702 acc= 62.44%  |  Jtest= 1.6332 acc= 64.00%
# iter=127:  Jtrain= 1.5665 acc= 62.30%  |  Jtest= 1.6325 acc= 63.26%
# iter=128:  Jtrain= 1.5643 acc= 62.26%  |  Jtest= 1.6293 acc= 64.15%
# iter=129:  Jtrain= 1.5635 acc= 62.52%  |  Jtest= 1.6273 acc= 65.04%
# iter=130:  Jtrain= 1.5617 acc= 62.44%  |  Jtest= 1.6265 acc= 64.74%
# iter=131:  Jtrain= 1.5605 acc= 62.70%  |  Jtest= 1.6264 acc= 64.89%
# iter=132:  Jtrain= 1.5544 acc= 63.04%  |  Jtest= 1.6245 acc= 64.30%
# iter=133:  Jtrain= 1.5543 acc= 62.96%  |  Jtest= 1.6243 acc= 64.30%
# iter=134:  Jtrain= 1.5541 acc= 63.15%  |  Jtest= 1.6235 acc= 64.74%
# iter=135:  Jtrain= 1.5539 acc= 63.04%  |  Jtest= 1.6230 acc= 65.33%
# iter=136:  Jtrain= 1.5530 acc= 63.11%  |  Jtest= 1.6219 acc= 65.63%
# iter=137:  Jtrain= 1.5519 acc= 63.00%  |  Jtest= 1.6218 acc= 64.89%
# iter=138:  Jtrain= 1.5505 acc= 63.15%  |  Jtest= 1.6215 acc= 64.30%
# iter=139:  Jtrain= 1.5504 acc= 63.15%  |  Jtest= 1.6213 acc= 65.04%
# iter=140:  Jtrain= 1.5503 acc= 63.04%  |  Jtest= 1.6214 acc= 64.44%
# iter=141:  Jtrain= 1.5501 acc= 63.04%  |  Jtest= 1.6220 acc= 64.30%
# iter=142:  Jtrain= 1.5303 acc= 63.67%  |  Jtest= 1.6166 acc= 64.59%
# iter=143:  Jtrain= 1.5235 acc= 64.07%  |  Jtest= 1.6119 acc= 65.19%
# iter=144:  Jtrain= 1.5192 acc= 64.37%  |  Jtest= 1.6101 acc= 64.89%
# iter=145:  Jtrain= 1.5175 acc= 64.41%  |  Jtest= 1.6090 acc= 64.59%
# iter=146:  Jtrain= 1.5168 acc= 64.41%  |  Jtest= 1.6076 acc= 65.04%
# iter=147:  Jtrain= 1.5152 acc= 64.22%  |  Jtest= 1.6071 acc= 65.19%
# iter=148:  Jtrain= 1.5138 acc= 64.56%  |  Jtest= 1.6081 acc= 64.44%
# iter=149:  Jtrain= 1.5047 acc= 65.00%  |  Jtest= 1.6028 acc= 64.89%
# iter=181:  Jtrain= 1.4218 acc= 70.07%  |  Jtest= 1.5258 acc= 70.81%
# iter=182:  Jtrain= 1.4214 acc= 70.00%  |  Jtest= 1.5260 acc= 70.81%
# iter=183:  Jtrain= 1.4213 acc= 70.00%  |  Jtest= 1.5256 acc= 71.26%
# iter=184:  Jtrain= 1.4203 acc= 70.11%  |  Jtest= 1.5237 acc= 71.26%
# iter=185:  Jtrain= 1.4200 acc= 69.93%  |  Jtest= 1.5235 acc= 71.26%
# iter=186:  Jtrain= 1.4195 acc= 69.81%  |  Jtest= 1.5230 acc= 70.96%
# iter=187:  Jtrain= 1.4193 acc= 70.00%  |  Jtest= 1.5226 acc= 70.81%
# iter=188:  Jtrain= 1.4191 acc= 70.00%  |  Jtest= 1.5226 acc= 71.41%
# iter=189:  Jtrain= 1.4190 acc= 69.96%  |  Jtest= 1.5228 acc= 71.56%
# iter=190:  Jtrain= 1.4186 acc= 69.96%  |  Jtest= 1.5221 acc= 71.11%
# iter=191:  Jtrain= 1.4175 acc= 70.00%  |  Jtest= 1.5204 acc= 71.11%
# iter=192:  Jtrain= 1.4155 acc= 70.22%  |  Jtest= 1.5167 acc= 71.70%
# iter=193:  Jtrain= 1.4131 acc= 70.44%  |  Jtest= 1.5143 acc= 71.56%
# iter=194:  Jtrain= 1.4122 acc= 70.26%  |  Jtest= 1.5140 acc= 71.85%
# iter=195:  Jtrain= 1.4120 acc= 70.33%  |  Jtest= 1.5142 acc= 71.70%
# iter=196:  Jtrain= 1.4117 acc= 70.37%  |  Jtest= 1.5136 acc= 71.70%
# iter=197:  Jtrain= 1.4112 acc= 70.56%  |  Jtest= 1.5128 acc= 71.70%
# iter=198:  Jtrain= 1.4101 acc= 70.26%  |  Jtest= 1.5123 acc= 72.15%
# iter=199:  Jtrain= 1.4087 acc= 70.15%  |  Jtest= 1.5122 acc= 71.41%
# iter=200:  Jtrain= 1.4069 acc= 70.26%  |  Jtest= 1.5106 acc= 72.15%
# iter=201:  Jtrain= 1.4053 acc= 70.70%  |  Jtest= 1.5080 acc= 72.00%
# iter=202:  Jtrain= 1.4049 acc= 70.70%  |  Jtest= 1.5072 acc= 72.30%
# iter=203:  Jtrain= 1.4040 acc= 70.41%  |  Jtest= 1.5067 acc= 72.15%
# iter=204:  Jtrain= 1.4036 acc= 70.48%  |  Jtest= 1.5071 acc= 71.70%
# iter=205:  Jtrain= 1.4035 acc= 70.41%  |  Jtest= 1.5070 acc= 71.85%
# iter=206:  Jtrain= 1.4032 acc= 70.56%  |  Jtest= 1.5063 acc= 72.00%
# iter=207:  Jtrain= 1.4029 acc= 70.52%  |  Jtest= 1.5060 acc= 72.30%
# iter=208:  Jtrain= 1.4026 acc= 70.41%  |  Jtest= 1.5058 acc= 72.30%
# iter=209:  Jtrain= 1.4013 acc= 70.19%  |  Jtest= 1.5067 acc= 71.85%
# iter=210:  Jtrain= 1.3995 acc= 70.74%  |  Jtest= 1.5061 acc= 71.85%
# iter=242:  Jtrain= 1.3393 acc= 71.93%  |  Jtest= 1.4729 acc= 74.22%
# iter=243:  Jtrain= 1.3359 acc= 72.22%  |  Jtest= 1.4735 acc= 74.67%
# iter=244:  Jtrain= 1.3292 acc= 73.04%  |  Jtest= 1.4735 acc= 73.78%
# iter=245:  Jtrain= 1.3236 acc= 73.04%  |  Jtest= 1.4728 acc= 74.07%
# iter=246:  Jtrain= 1.3200 acc= 73.33%  |  Jtest= 1.4764 acc= 73.48%
# iter=247:  Jtrain= 1.3189 acc= 73.48%  |  Jtest= 1.4766 acc= 73.33%
# iter=248:  Jtrain= 1.3180 acc= 73.37%  |  Jtest= 1.4795 acc= 73.93%
# iter=249:  Jtrain= 1.3171 acc= 73.37%  |  Jtest= 1.4824 acc= 74.07%
# iter=250:  Jtrain= 1.3154 acc= 73.44%  |  Jtest= 1.4852 acc= 73.93%
# iter=251:  Jtrain= 1.3152 acc= 73.63%  |  Jtest= 1.4860 acc= 74.07%
# iter=252:  Jtrain= 1.3151 acc= 73.22%  |  Jtest= 1.4863 acc= 74.07%
# iter=253:  Jtrain= 1.3149 acc= 73.52%  |  Jtest= 1.4869 acc= 74.07%
# iter=254:  Jtrain= 1.3132 acc= 73.33%  |  Jtest= 1.4919 acc= 73.93%
# iter=255:  Jtrain= 1.3124 acc= 73.70%  |  Jtest= 1.4945 acc= 74.22%
# iter=256:  Jtrain= 1.3121 acc= 73.52%  |  Jtest= 1.4951 acc= 73.78%
# iter=257:  Jtrain= 1.3120 acc= 73.63%  |  Jtest= 1.4954 acc= 73.93%
# iter=258:  Jtrain= 1.3119 acc= 73.52%  |  Jtest= 1.4956 acc= 73.63%
# iter=259:  Jtrain= 1.3114 acc= 73.56%  |  Jtest= 1.4970 acc= 73.78%
# iter=260:  Jtrain= 1.3103 acc= 73.52%  |  Jtest= 1.4993 acc= 73.48%
# iter=261:  Jtrain= 1.3098 acc= 73.48%  |  Jtest= 1.5026 acc= 73.48%
# iter=262:  Jtrain= 1.3087 acc= 73.67%  |  Jtest= 1.5048 acc= 73.33%
# iter=263:  Jtrain= 1.3084 acc= 73.63%  |  Jtest= 1.5052 acc= 73.63%
# iter=264:  Jtrain= 1.3083 acc= 73.63%  |  Jtest= 1.5055 acc= 73.33%
# iter=265:  Jtrain= 1.3082 acc= 73.56%  |  Jtest= 1.5058 acc= 73.33%
# iter=266:  Jtrain= 1.3078 acc= 73.56%  |  Jtest= 1.5065 acc= 73.48%
# iter=267:  Jtrain= 1.3074 acc= 73.33%  |  Jtest= 1.5069 acc= 73.93%
# iter=268:  Jtrain= 1.3072 acc= 73.30%  |  Jtest= 1.5078 acc= 73.63%
# iter=269:  Jtrain= 1.3062 acc= 73.56%  |  Jtest= 1.5081 acc= 73.48%
# iter=270:  Jtrain= 1.3061 acc= 73.67%  |  Jtest= 1.5080 acc= 73.78%
# iter=271:  Jtrain= 1.3060 acc= 73.59%  |  Jtest= 1.5079 acc= 74.07%
# iter=272:  Jtrain= 1.3058 acc= 73.81%  |  Jtest= 1.5079 acc= 73.63%
# iter=273:  Jtrain= 1.3044 acc= 74.00%  |  Jtest= 1.5067 acc= 73.63%
# iter=274:  Jtrain= 1.3037 acc= 73.70%  |  Jtest= 1.5059 acc= 73.63%
# iter=275:  Jtrain= 1.3025 acc= 73.63%  |  Jtest= 1.5052 acc= 73.78%
# iter=276:  Jtrain= 1.3014 acc= 74.15%  |  Jtest= 1.5047 acc= 74.07%
# iter=277:  Jtrain= 1.3013 acc= 74.15%  |  Jtest= 1.5047 acc= 74.22%
# iter=278:  Jtrain= 1.3013 acc= 74.04%  |  Jtest= 1.5046 acc= 74.22%
# iter=279:  Jtrain= 1.3007 acc= 73.93%  |  Jtest= 1.5041 acc= 74.22%
# iter=280:  Jtrain= 1.2996 acc= 74.19%  |  Jtest= 1.5037 acc= 73.48%
# iter=281:  Jtrain= 1.2988 acc= 74.15%  |  Jtest= 1.5037 acc= 74.52%
# iter=282:  Jtrain= 1.2982 acc= 74.11%  |  Jtest= 1.5035 acc= 73.78%
# iter=283:  Jtrain= 1.2981 acc= 74.00%  |  Jtest= 1.5032 acc= 73.63%
# iter=284:  Jtrain= 1.2979 acc= 74.19%  |  Jtest= 1.5030 acc= 74.07%
# iter=285:  Jtrain= 1.2977 acc= 74.37%  |  Jtest= 1.5032 acc= 73.63%
# iter=286:  Jtrain= 1.2963 acc= 73.93%  |  Jtest= 1.5026 acc= 73.93%
# iter=287:  Jtrain= 1.2936 acc= 74.22%  |  Jtest= 1.5032 acc= 73.63%
# iter=288:  Jtrain= 1.2923 acc= 74.22%  |  Jtest= 1.5048 acc= 73.48%
# iter=289:  Jtrain= 1.2912 acc= 73.96%  |  Jtest= 1.5031 acc= 72.89%
# iter=290:  Jtrain= 1.2912 acc= 73.96%  |  Jtest= 1.5031 acc= 72.89%
# iter=291:  Jtrain= 1.2911 acc= 74.37%  |  Jtest= 1.5032 acc= 73.33%
# iter=292:  Jtrain= 1.2909 acc= 74.11%  |  Jtest= 1.5024 acc= 72.74%
# iter=293:  Jtrain= 1.2884 acc= 74.78%  |  Jtest= 1.4997 acc= 73.19%
# iter=294:  Jtrain= 1.2873 acc= 74.26%  |  Jtest= 1.4985 acc= 73.33%
# iter=295:  Jtrain= 1.2872 acc= 74.56%  |  Jtest= 1.4985 acc= 73.33%
# iter=296:  Jtrain= 1.2872 acc= 74.26%  |  Jtest= 1.4986 acc= 72.89%
# iter=297:  Jtrain= 1.2870 acc= 74.37%  |  Jtest= 1.4989 acc= 73.19%
# iter=298:  Jtrain= 1.2862 acc= 74.15%  |  Jtest= 1.4985 acc= 73.04%
# iter=299:  Jtrain= 1.2812 acc= 75.00%  |  Jtest= 1.4964 acc= 73.33%
# iter=300:  Jtrain= 1.2703 acc= 74.96%  |  Jtest= 1.4894 acc= 73.48%
# iter=301:  Jtrain= 1.2686 acc= 74.89%  |  Jtest= 1.4904 acc= 73.33%
# iter=302:  Jtrain= 1.2682 acc= 74.74%  |  Jtest= 1.4909 acc= 72.30%
# iter=303:  Jtrain= 1.2680 acc= 74.56%  |  Jtest= 1.4913 acc= 72.59%
# iter=304:  Jtrain= 1.2679 acc= 74.81%  |  Jtest= 1.4921 acc= 72.59%
# iter=305:  Jtrain= 1.2634 acc= 74.96%  |  Jtest= 1.4945 acc= 71.70%
# iter=306:  Jtrain= 1.2612 acc= 74.89%  |  Jtest= 1.4933 acc= 72.30%
# iter=307:  Jtrain= 1.2611 acc= 74.74%  |  Jtest= 1.4929 acc= 72.15%
# iter=308:  Jtrain= 1.2610 acc= 74.78%  |  Jtest= 1.4924 acc= 72.74%
# iter=309:  Jtrain= 1.2609 acc= 74.96%  |  Jtest= 1.4931 acc= 72.59%
# iter=310:  Jtrain= 1.2602 acc= 75.04%  |  Jtest= 1.4949 acc= 72.59%
# iter=311:  Jtrain= 1.2590 acc= 74.63%  |  Jtest= 1.4972 acc= 72.44%
# iter=312:  Jtrain= 1.2582 acc= 74.70%  |  Jtest= 1.4982 acc= 72.44%
# iter=313:  Jtrain= 1.2579 acc= 74.78%  |  Jtest= 1.4977 acc= 72.44%
# iter=314:  Jtrain= 1.2578 acc= 74.93%  |  Jtest= 1.4984 acc= 72.30%
# iter=315:  Jtrain= 1.2578 acc= 74.96%  |  Jtest= 1.4988 acc= 72.59%
# iter=316:  Jtrain= 1.2578 acc= 74.85%  |  Jtest= 1.4990 acc= 72.30%
# iter=317:  Jtrain= 1.2576 acc= 74.70%  |  Jtest= 1.4980 acc= 72.30%
# iter=318:  Jtrain= 1.2573 acc= 74.67%  |  Jtest= 1.4978 acc= 72.44%
# iter=319:  Jtrain= 1.2569 acc= 74.74%  |  Jtest= 1.5002 acc= 72.30%
# iter=320:  Jtrain= 1.2565 acc= 74.74%  |  Jtest= 1.5015 acc= 72.89%
# iter=321:  Jtrain= 1.2563 acc= 74.67%  |  Jtest= 1.4999 acc= 72.30%
# iter=322:  Jtrain= 1.2562 acc= 74.78%  |  Jtest= 1.4995 acc= 72.30%
# iter=323:  Jtrain= 1.2560 acc= 74.85%  |  Jtest= 1.5000 acc= 72.00%
# iter=324:  Jtrain= 1.2559 acc= 74.74%  |  Jtest= 1.5000 acc= 72.44%
# iter=325:  Jtrain= 1.2559 acc= 74.81%  |  Jtest= 1.5001 acc= 72.44%
# iter=326:  Jtrain= 1.2559 acc= 74.78%  |  Jtest= 1.5004 acc= 72.59%
# iter=327:  Jtrain= 1.2556 acc= 74.85%  |  Jtest= 1.5009 acc= 72.59%
# iter=328:  Jtrain= 1.2549 acc= 74.74%  |  Jtest= 1.4991 acc= 72.30%
# iter=329:  Jtrain= 1.2544 acc= 74.74%  |  Jtest= 1.4987 acc= 72.30%
# iter=330:  Jtrain= 1.2543 acc= 74.85%  |  Jtest= 1.4991 acc= 72.59%
# iter=331:  Jtrain= 1.2543 acc= 74.74%  |  Jtest= 1.4991 acc= 72.15%
# iter=332:  Jtrain= 1.2542 acc= 74.70%  |  Jtest= 1.4991 acc= 72.15%
# iter=333:  Jtrain= 1.2542 acc= 74.85%  |  Jtest= 1.4994 acc= 72.15%
# iter=334:  Jtrain= 1.2540 acc= 74.85%  |  Jtest= 1.4993 acc= 72.30%
# iter=335:  Jtrain= 1.2535 acc= 74.70%  |  Jtest= 1.4986 acc= 72.30%
# iter=336:  Jtrain= 1.2526 acc= 74.93%  |  Jtest= 1.4978 acc= 72.59%
# iter=337:  Jtrain= 1.2522 acc= 74.78%  |  Jtest= 1.4979 acc= 72.30%
# iter=338:  Jtrain= 1.2520 acc= 74.93%  |  Jtest= 1.4994 acc= 72.15%
# iter=339:  Jtrain= 1.2520 acc= 74.81%  |  Jtest= 1.4993 acc= 72.15%
# iter=340:  Jtrain= 1.2520 acc= 74.81%  |  Jtest= 1.4990 acc= 72.15%
# iter=341:  Jtrain= 1.2519 acc= 74.89%  |  Jtest= 1.4991 acc= 72.44%
# iter=342:  Jtrain= 1.2519 acc= 74.96%  |  Jtest= 1.4995 acc= 72.30%
# iter=343:  Jtrain= 1.2518 acc= 74.89%  |  Jtest= 1.4997 acc= 72.15%
# iter=344:  Jtrain= 1.2516 acc= 74.93%  |  Jtest= 1.5001 acc= 72.15%
# iter=345:  Jtrain= 1.2515 acc= 74.89%  |  Jtest= 1.4993 acc= 72.30%
# iter=346:  Jtrain= 1.2514 acc= 74.93%  |  Jtest= 1.4989 acc= 72.15%
# iter=347:  Jtrain= 1.2514 acc= 74.74%  |  Jtest= 1.4988 acc= 72.30%
# iter=348:  Jtrain= 1.2514 acc= 74.85%  |  Jtest= 1.4990 acc= 72.15%
# iter=349:  Jtrain= 1.2513 acc= 74.93%  |  Jtest= 1.4991 acc= 72.44%
# iter=350:  Jtrain= 1.2513 acc= 74.81%  |  Jtest= 1.4991 acc= 72.00%
# iter=351:  Jtrain= 1.2513 acc= 74.89%  |  Jtest= 1.4993 acc= 72.15%
# iter=352:  Jtrain= 1.2512 acc= 75.00%  |  Jtest= 1.4996 acc= 72.30%
# iter=353:  Jtrain= 1.2511 acc= 75.04%  |  Jtest= 1.4992 acc= 72.15%
# iter=354:  Jtrain= 1.2509 acc= 74.93%  |  Jtest= 1.4985 acc= 72.44%
# iter=355:  Jtrain= 1.2507 acc= 74.78%  |  Jtest= 1.4988 acc= 72.30%
# iter=356:  Jtrain= 1.2507 acc= 74.89%  |  Jtest= 1.4992 acc= 72.44%
# iter=357:  Jtrain= 1.2507 acc= 74.96%  |  Jtest= 1.4996 acc= 72.30%
# iter=358:  Jtrain= 1.2507 acc= 74.93%  |  Jtest= 1.4995 acc= 72.00%
# iter=359:  Jtrain= 1.2506 acc= 74.93%  |  Jtest= 1.4993 acc= 72.30%
# iter=360:  Jtrain= 1.2506 acc= 74.89%  |  Jtest= 1.4990 acc= 72.59%
# iter=361:  Jtrain= 1.2506 acc= 74.93%  |  Jtest= 1.4988 acc= 72.44%
# iter=362:  Jtrain= 1.2505 acc= 74.96%  |  Jtest= 1.4993 acc= 72.30%
# iter=363:  Jtrain= 1.2504 acc= 75.04%  |  Jtest= 1.5003 acc= 72.30%
# iter=364:  Jtrain= 1.2502 acc= 74.89%  |  Jtest= 1.5005 acc= 72.30%
# iter=365:  Jtrain= 1.2500 acc= 74.81%  |  Jtest= 1.4995 acc= 72.30%
# iter=366:  Jtrain= 1.2498 acc= 75.04%  |  Jtest= 1.4995 acc= 72.44%
# iter=367:  Jtrain= 1.2498 acc= 75.00%  |  Jtest= 1.4995 acc= 72.59%
# iter=368:  Jtrain= 1.2497 acc= 74.96%  |  Jtest= 1.4994 acc= 72.30%
# iter=369:  Jtrain= 1.2496 acc= 74.85%  |  Jtest= 1.5002 acc= 72.30%
# iter=370:  Jtrain= 1.2496 acc= 74.93%  |  Jtest= 1.5004 acc= 72.44%
# iter=371:  Jtrain= 1.2495 acc= 75.07%  |  Jtest= 1.5002 acc= 72.30%
# iter=372:  Jtrain= 1.2495 acc= 74.96%  |  Jtest= 1.5000 acc= 72.44%
# iter=373:  Jtrain= 1.2495 acc= 74.93%  |  Jtest= 1.5001 acc= 72.59%
# iter=374:  Jtrain= 1.2494 acc= 75.00%  |  Jtest= 1.5001 acc= 72.44%
# iter=375:  Jtrain= 1.2490 acc= 75.00%  |  Jtest= 1.4991 acc= 72.30%
# iter=376:  Jtrain= 1.2433 acc= 75.37%  |  Jtest= 1.5126 acc= 72.00%
# iter=377:  Jtrain= 1.2421 acc= 75.33%  |  Jtest= 1.5165 acc= 71.70%
# iter=378:  Jtrain= 1.2417 acc= 75.59%  |  Jtest= 1.5170 acc= 72.30%
# iter=379:  Jtrain= 1.2415 acc= 75.67%  |  Jtest= 1.5185 acc= 71.85%
# iter=380:  Jtrain= 1.2387 acc= 75.81%  |  Jtest= 1.5260 acc= 71.70%
# iter=381:  Jtrain= 1.2305 acc= 76.00%  |  Jtest= 1.5430 acc= 70.67%
# iter=382:  Jtrain= 1.2145 acc= 76.48%  |  Jtest= 1.5806 acc= 72.00%
# iter=383:  Jtrain= 1.2116 acc= 77.07%  |  Jtest= 1.5770 acc= 70.96%
# iter=384:  Jtrain= 1.2099 acc= 76.96%  |  Jtest= 1.5701 acc= 71.85%
# iter=385:  Jtrain= 1.2098 acc= 77.00%  |  Jtest= 1.5699 acc= 71.70%
# iter=386:  Jtrain= 1.2098 acc= 76.93%  |  Jtest= 1.5692 acc= 71.56%
# iter=387:  Jtrain= 1.2097 acc= 76.96%  |  Jtest= 1.5686 acc= 71.56%
# iter=388:  Jtrain= 1.2081 acc= 77.19%  |  Jtest= 1.5624 acc= 72.44%
# iter=389:  Jtrain= 1.2072 acc= 77.19%  |  Jtest= 1.5621 acc= 71.70%
# iter=390:  Jtrain= 1.2065 acc= 77.19%  |  Jtest= 1.5613 acc= 72.15%
# iter=391:  Jtrain= 1.2065 acc= 77.26%  |  Jtest= 1.5614 acc= 72.00%
# iter=392:  Jtrain= 1.2065 acc= 77.19%  |  Jtest= 1.5615 acc= 72.00%
# iter=393:  Jtrain= 1.2065 acc= 77.26%  |  Jtest= 1.5612 acc= 72.15%
# iter=394:  Jtrain= 1.2064 acc= 77.22%  |  Jtest= 1.5605 acc= 72.30%
# iter=395:  Jtrain= 1.2063 acc= 77.22%  |  Jtest= 1.5613 acc= 71.56%
# iter=396:  Jtrain= 1.2062 acc= 77.15%  |  Jtest= 1.5620 acc= 71.41%
# iter=397:  Jtrain= 1.2061 acc= 77.26%  |  Jtest= 1.5616 acc= 72.00%
# iter=398:  Jtrain= 1.2061 acc= 77.30%  |  Jtest= 1.5612 acc= 72.15%
# iter=399:  Jtrain= 1.2060 acc= 77.19%  |  Jtest= 1.5613 acc= 72.00%
# iter=400:  Jtrain= 1.2060 acc= 77.19%  |  Jtest= 1.5606 acc= 72.15%
# iter=401:  Jtrain= 1.2044 acc= 77.22%  |  Jtest= 1.5618 acc= 71.41%
# iter=402:  Jtrain= 1.2041 acc= 77.22%  |  Jtest= 1.5609 acc= 71.85%
# iter=403:  Jtrain= 1.2041 acc= 77.19%  |  Jtest= 1.5614 acc= 71.85%
# iter=404:  Jtrain= 1.2041 acc= 77.19%  |  Jtest= 1.5616 acc= 71.85%
# iter=405:  Jtrain= 1.2040 acc= 77.11%  |  Jtest= 1.5619 acc= 71.85%
# iter=406:  Jtrain= 1.2040 acc= 77.19%  |  Jtest= 1.5613 acc= 71.85%
# iter=407:  Jtrain= 1.2038 acc= 77.30%  |  Jtest= 1.5610 acc= 71.85%
# iter=408:  Jtrain= 1.2036 acc= 77.44%  |  Jtest= 1.5596 acc= 72.15%
# iter=409:  Jtrain= 1.2016 acc= 77.37%  |  Jtest= 1.5603 acc= 72.30%
# iter=410:  Jtrain= 1.1996 acc= 77.44%  |  Jtest= 1.5637 acc= 72.15%
# iter=411:  Jtrain= 1.1987 acc= 77.07%  |  Jtest= 1.5624 acc= 72.15%
# iter=412:  Jtrain= 1.1985 acc= 77.00%  |  Jtest= 1.5618 acc= 72.30%
# iter=413:  Jtrain= 1.1984 acc= 77.00%  |  Jtest= 1.5607 acc= 72.30%
# iter=414:  Jtrain= 1.1984 acc= 77.07%  |  Jtest= 1.5608 acc= 72.44%
# iter=415:  Jtrain= 1.1984 acc= 77.07%  |  Jtest= 1.5611 acc= 72.44%
# iter=416:  Jtrain= 1.1984 acc= 76.96%  |  Jtest= 1.5615 acc= 72.15%
# iter=417:  Jtrain= 1.1983 acc= 76.93%  |  Jtest= 1.5608 acc= 72.30%
# iter=418:  Jtrain= 1.1983 acc= 77.00%  |  Jtest= 1.5604 acc= 72.44%
# iter=419:  Jtrain= 1.1982 acc= 77.11%  |  Jtest= 1.5605 acc= 72.15%
# iter=420:  Jtrain= 1.1979 acc= 77.04%  |  Jtest= 1.5627 acc= 72.15%
# iter=421:  Jtrain= 1.1977 acc= 77.00%  |  Jtest= 1.5622 acc= 72.30%
# iter=422:  Jtrain= 1.1973 acc= 77.11%  |  Jtest= 1.5614 acc= 72.30%
# iter=423:  Jtrain= 1.1971 acc= 77.07%  |  Jtest= 1.5608 acc= 72.15%
# iter=424:  Jtrain= 1.1971 acc= 77.26%  |  Jtest= 1.5612 acc= 72.30%
# iter=425:  Jtrain= 1.1970 acc= 77.15%  |  Jtest= 1.5619 acc= 72.15%
# iter=426:  Jtrain= 1.1970 acc= 77.19%  |  Jtest= 1.5619 acc= 72.30%
# iter=427:  Jtrain= 1.1970 acc= 77.15%  |  Jtest= 1.5615 acc= 72.30%
# iter=428:  Jtrain= 1.1970 acc= 77.11%  |  Jtest= 1.5616 acc= 72.15%
# iter=429:  Jtrain= 1.1970 acc= 77.22%  |  Jtest= 1.5616 acc= 72.15%
# iter=430:  Jtrain= 1.1969 acc= 77.22%  |  Jtest= 1.5618 acc= 72.15%
# iter=431:  Jtrain= 1.1969 acc= 77.22%  |  Jtest= 1.5624 acc= 72.30%
# iter=432:  Jtrain= 1.1968 acc= 77.19%  |  Jtest= 1.5620 acc= 72.30%
# iter=433:  Jtrain= 1.1968 acc= 77.22%  |  Jtest= 1.5615 acc= 72.30%
# iter=434:  Jtrain= 1.1968 acc= 77.22%  |  Jtest= 1.5611 acc= 72.30%
# iter=435:  Jtrain= 1.1967 acc= 77.11%  |  Jtest= 1.5612 acc= 72.30%
# iter=436:  Jtrain= 1.1967 acc= 77.19%  |  Jtest= 1.5620 acc= 72.30%
# iter=437:  Jtrain= 1.1966 acc= 77.22%  |  Jtest= 1.5617 acc= 72.30%
# iter=438:  Jtrain= 1.1966 acc= 77.33%  |  Jtest= 1.5607 acc= 72.30%
# iter=439:  Jtrain= 1.1965 acc= 77.22%  |  Jtest= 1.5603 acc= 72.30%
# iter=440:  Jtrain= 1.1961 acc= 77.30%  |  Jtest= 1.5627 acc= 72.44%
# iter=441:  Jtrain= 1.1958 acc= 77.22%  |  Jtest= 1.5629 acc= 72.30%
# iter=442:  Jtrain= 1.1957 acc= 77.37%  |  Jtest= 1.5633 acc= 72.30%
# iter=443:  Jtrain= 1.1952 acc= 77.26%  |  Jtest= 1.5633 acc= 72.30%
# iter=444:  Jtrain= 1.1948 acc= 77.26%  |  Jtest= 1.5604 acc= 72.59%
# iter=445:  Jtrain= 1.1948 acc= 77.44%  |  Jtest= 1.5603 acc= 72.59%
# iter=446:  Jtrain= 1.1947 acc= 77.26%  |  Jtest= 1.5613 acc= 72.74%
# iter=447:  Jtrain= 1.1946 acc= 77.48%  |  Jtest= 1.5621 acc= 72.44%
# iter=448:  Jtrain= 1.1942 acc= 77.37%  |  Jtest= 1.5640 acc= 72.44%
# iter=449:  Jtrain= 1.1937 acc= 77.56%  |  Jtest= 1.5631 acc= 72.74%
# iter=450:  Jtrain= 1.1936 acc= 77.56%  |  Jtest= 1.5634 acc= 72.74%
# iter=451:  Jtrain= 1.1935 acc= 77.74%  |  Jtest= 1.5635 acc= 72.74%
# iter=452:  Jtrain= 1.1934 acc= 77.85%  |  Jtest= 1.5635 acc= 72.89%
# iter=453:  Jtrain= 1.1933 acc= 77.63%  |  Jtest= 1.5649 acc= 72.74%
# iter=454:  Jtrain= 1.1933 acc= 77.67%  |  Jtest= 1.5662 acc= 73.19%
# iter=455:  Jtrain= 1.1932 acc= 77.70%  |  Jtest= 1.5666 acc= 72.74%
# iter=456:  Jtrain= 1.1930 acc= 77.85%  |  Jtest= 1.5658 acc= 72.89%
# iter=457:  Jtrain= 1.1929 acc= 77.74%  |  Jtest= 1.5665 acc= 72.89%
# iter=458:  Jtrain= 1.1926 acc= 77.59%  |  Jtest= 1.5689 acc= 72.74%
# iter=459:  Jtrain= 1.1923 acc= 77.59%  |  Jtest= 1.5710 acc= 72.74%
# iter=460:  Jtrain= 1.1922 acc= 77.70%  |  Jtest= 1.5702 acc= 72.74%
# iter=461:  Jtrain= 1.1921 acc= 77.59%  |  Jtest= 1.5695 acc= 72.74%
# iter=462:  Jtrain= 1.1921 acc= 77.63%  |  Jtest= 1.5697 acc= 72.74%
# iter=463:  Jtrain= 1.1911 acc= 77.63%  |  Jtest= 1.5733 acc= 72.59%
# iter=464:  Jtrain= 1.1906 acc= 77.26%  |  Jtest= 1.5719 acc= 72.74%
# iter=465:  Jtrain= 1.1901 acc= 77.33%  |  Jtest= 1.5712 acc= 72.89%
# iter=466:  Jtrain= 1.1897 acc= 77.33%  |  Jtest= 1.5723 acc= 72.15%
# iter=467:  Jtrain= 1.1896 acc= 77.37%  |  Jtest= 1.5727 acc= 72.00%
# iter=468:  Jtrain= 1.1896 acc= 77.26%  |  Jtest= 1.5725 acc= 72.00%
# iter=469:  Jtrain= 1.1896 acc= 77.19%  |  Jtest= 1.5727 acc= 72.15%
# iter=470:  Jtrain= 1.1896 acc= 77.37%  |  Jtest= 1.5729 acc= 72.30%
# iter=471:  Jtrain= 1.1895 acc= 77.33%  |  Jtest= 1.5726 acc= 72.00%
# iter=472:  Jtrain= 1.1894 acc= 77.44%  |  Jtest= 1.5718 acc= 72.30%
# iter=473:  Jtrain= 1.1889 acc= 77.59%  |  Jtest= 1.5736 acc= 72.00%
# iter=474:  Jtrain= 1.1875 acc= 77.44%  |  Jtest= 1.5742 acc= 72.59%
# iter=475:  Jtrain= 1.1873 acc= 77.44%  |  Jtest= 1.5763 acc= 72.30%
# iter=476:  Jtrain= 1.1872 acc= 77.48%  |  Jtest= 1.5762 acc= 72.30%
# iter=477:  Jtrain= 1.1872 acc= 77.44%  |  Jtest= 1.5756 acc= 72.44%
# iter=478:  Jtrain= 1.1872 acc= 77.37%  |  Jtest= 1.5755 acc= 72.30%
# iter=479:  Jtrain= 1.1865 acc= 77.59%  |  Jtest= 1.5719 acc= 72.89%
# iter=480:  Jtrain= 1.1864 acc= 77.63%  |  Jtest= 1.5724 acc= 72.89%
# iter=481:  Jtrain= 1.1864 acc= 77.63%  |  Jtest= 1.5727 acc= 72.89%
# iter=482:  Jtrain= 1.1864 acc= 77.59%  |  Jtest= 1.5726 acc= 72.89%
# iter=483:  Jtrain= 1.1864 acc= 77.63%  |  Jtest= 1.5727 acc= 73.04%
# iter=484:  Jtrain= 1.1863 acc= 77.56%  |  Jtest= 1.5721 acc= 72.74%
# iter=485:  Jtrain= 1.1861 acc= 77.59%  |  Jtest= 1.5715 acc= 72.89%
# iter=486:  Jtrain= 1.1855 acc= 77.67%  |  Jtest= 1.5741 acc= 72.59%
# iter=487:  Jtrain= 1.1850 acc= 77.78%  |  Jtest= 1.5770 acc= 72.00%
# iter=488:  Jtrain= 1.1850 acc= 77.63%  |  Jtest= 1.5782 acc= 72.44%
# iter=489:  Jtrain= 1.1847 acc= 77.63%  |  Jtest= 1.5773 acc= 72.44%
# iter=490:  Jtrain= 1.1846 acc= 77.74%  |  Jtest= 1.5760 acc= 72.15%
# iter=491:  Jtrain= 1.1840 acc= 77.81%  |  Jtest= 1.5752 acc= 72.00%
# iter=492:  Jtrain= 1.1838 acc= 77.67%  |  Jtest= 1.5741 acc= 72.89%
# iter=493:  Jtrain= 1.1836 acc= 77.81%  |  Jtest= 1.5745 acc= 72.44%
# iter=494:  Jtrain= 1.1836 acc= 77.74%  |  Jtest= 1.5750 acc= 72.74%
# iter=495:  Jtrain= 1.1836 acc= 77.78%  |  Jtest= 1.5750 acc= 72.44%
# iter=496:  Jtrain= 1.1836 acc= 77.78%  |  Jtest= 1.5749 acc= 72.59%
# iter=497:  Jtrain= 1.1836 acc= 77.78%  |  Jtest= 1.5750 acc= 72.74%
# iter=498:  Jtrain= 1.1836 acc= 77.74%  |  Jtest= 1.5752 acc= 72.74%
# iter=499:  Jtrain= 1.1835 acc= 77.70%  |  Jtest= 1.5752 acc= 72.74%
# iter=500:  Jtrain= 1.1835 acc= 77.81%  |  Jtest= 1.5752 acc= 72.89%
# iter=501:  Jtrain= 1.1834 acc= 77.74%  |  Jtest= 1.5766 acc= 72.74%
# iter=502:  Jtrain= 1.1828 acc= 77.59%  |  Jtest= 1.5805 acc= 72.30%
# iter=503:  Jtrain= 1.1827 acc= 77.59%  |  Jtest= 1.5810 acc= 72.30%
# iter=504:  Jtrain= 1.1827 acc= 77.67%  |  Jtest= 1.5812 acc= 72.44%
# iter=505:  Jtrain= 1.1827 acc= 77.67%  |  Jtest= 1.5811 acc= 72.30%
# iter=506:  Jtrain= 1.1822 acc= 77.89%  |  Jtest= 1.5770 acc= 72.89%
# iter=507:  Jtrain= 1.1821 acc= 77.74%  |  Jtest= 1.5772 acc= 72.74%
# iter=508:  Jtrain= 1.1821 acc= 77.78%  |  Jtest= 1.5771 acc= 72.74%
# iter=509:  Jtrain= 1.1821 acc= 77.78%  |  Jtest= 1.5774 acc= 72.89%
# iter=510:  Jtrain= 1.1816 acc= 77.59%  |  Jtest= 1.5807 acc= 72.15%
# iter=511:  Jtrain= 1.1811 acc= 77.81%  |  Jtest= 1.5807 acc= 72.44%
# iter=512:  Jtrain= 1.1806 acc= 78.07%  |  Jtest= 1.5818 acc= 72.59%
# iter=513:  Jtrain= 1.1805 acc= 77.93%  |  Jtest= 1.5816 acc= 72.59%
# iter=514:  Jtrain= 1.1804 acc= 78.00%  |  Jtest= 1.5814 acc= 72.59%
# iter=515:  Jtrain= 1.1804 acc= 77.78%  |  Jtest= 1.5816 acc= 72.44%
# iter=516:  Jtrain= 1.1793 acc= 77.93%  |  Jtest= 1.5829 acc= 72.00%
# iter=517:  Jtrain= 1.1789 acc= 77.96%  |  Jtest= 1.5809 acc= 72.44%
# iter=518:  Jtrain= 1.1789 acc= 78.00%  |  Jtest= 1.5804 acc= 72.59%
# iter=519:  Jtrain= 1.1788 acc= 78.04%  |  Jtest= 1.5813 acc= 72.15%
# iter=520:  Jtrain= 1.1786 acc= 78.04%  |  Jtest= 1.5819 acc= 72.30%
# iter=521:  Jtrain= 1.1786 acc= 78.07%  |  Jtest= 1.5817 acc= 72.44%
# iter=522:  Jtrain= 1.1786 acc= 78.07%  |  Jtest= 1.5818 acc= 72.44%
# iter=523:  Jtrain= 1.1786 acc= 78.04%  |  Jtest= 1.5815 acc= 72.44%
# iter=524:  Jtrain= 1.1781 acc= 77.63%  |  Jtest= 1.5872 acc= 72.30%
# iter=525:  Jtrain= 1.1780 acc= 77.70%  |  Jtest= 1.5885 acc= 71.85%
# iter=526:  Jtrain= 1.1780 acc= 77.74%  |  Jtest= 1.5883 acc= 72.00%
# iter=527:  Jtrain= 1.1780 acc= 77.70%  |  Jtest= 1.5881 acc= 72.15%
# iter=528:  Jtrain= 1.1779 acc= 77.78%  |  Jtest= 1.5882 acc= 72.15%
# iter=529:  Jtrain= 1.1777 acc= 77.63%  |  Jtest= 1.5900 acc= 72.00%
# iter=530:  Jtrain= 1.1773 acc= 77.93%  |  Jtest= 1.5946 acc= 71.85%
# iter=531:  Jtrain= 1.1768 acc= 77.93%  |  Jtest= 1.5950 acc= 72.15%
# iter=532:  Jtrain= 1.1766 acc= 78.04%  |  Jtest= 1.5946 acc= 72.15%
# iter=533:  Jtrain= 1.1766 acc= 77.89%  |  Jtest= 1.5945 acc= 72.00%
# iter=534:  Jtrain= 1.1766 acc= 77.85%  |  Jtest= 1.5943 acc= 72.30%
# iter=535:  Jtrain= 1.1763 acc= 77.96%  |  Jtest= 1.5951 acc= 72.30%
# iter=536:  Jtrain= 1.1760 acc= 77.93%  |  Jtest= 1.5966 acc= 71.85%
# iter=537:  Jtrain= 1.1743 acc= 78.19%  |  Jtest= 1.6005 acc= 71.56%
# iter=538:  Jtrain= 1.1727 acc= 78.26%  |  Jtest= 1.6024 acc= 72.00%
# iter=539:  Jtrain= 1.1720 acc= 78.26%  |  Jtest= 1.6049 acc= 72.15%
# iter=540:  Jtrain= 1.1717 acc= 78.07%  |  Jtest= 1.6056 acc= 72.44%
# iter=541:  Jtrain= 1.1716 acc= 78.00%  |  Jtest= 1.6050 acc= 72.15%
# iter=542:  Jtrain= 1.1709 acc= 78.04%  |  Jtest= 1.6019 acc= 72.44%
# iter=543:  Jtrain= 1.1694 acc= 78.15%  |  Jtest= 1.6018 acc= 72.15%
# iter=544:  Jtrain= 1.1692 acc= 78.19%  |  Jtest= 1.6028 acc= 71.85%
# iter=545:  Jtrain= 1.1691 acc= 78.15%  |  Jtest= 1.6017 acc= 72.30%
# iter=546:  Jtrain= 1.1691 acc= 78.15%  |  Jtest= 1.6014 acc= 72.00%
# iter=547:  Jtrain= 1.1691 acc= 78.19%  |  Jtest= 1.6016 acc= 71.85%
# iter=548:  Jtrain= 1.1690 acc= 78.15%  |  Jtest= 1.6018 acc= 72.00%
# iter=549:  Jtrain= 1.1690 acc= 78.19%  |  Jtest= 1.6017 acc= 71.85%
# iter=550:  Jtrain= 1.1689 acc= 78.22%  |  Jtest= 1.6009 acc= 72.00%
# iter=551:  Jtrain= 1.1687 acc= 78.15%  |  Jtest= 1.6008 acc= 71.85%
# iter=552:  Jtrain= 1.1686 acc= 78.26%  |  Jtest= 1.6001 acc= 72.44%
# iter=553:  Jtrain= 1.1686 acc= 78.26%  |  Jtest= 1.5999 acc= 72.44%
# iter=554:  Jtrain= 1.1686 acc= 78.33%  |  Jtest= 1.6000 acc= 72.30%
# iter=555:  Jtrain= 1.1686 acc= 78.26%  |  Jtest= 1.6002 acc= 72.44%
# iter=556:  Jtrain= 1.1686 acc= 78.22%  |  Jtest= 1.6004 acc= 72.30%
# iter=557:  Jtrain= 1.1685 acc= 78.19%  |  Jtest= 1.6001 acc= 72.15%
# iter=558:  Jtrain= 1.1683 acc= 78.19%  |  Jtest= 1.6008 acc= 72.30%
# iter=559:  Jtrain= 1.1682 acc= 78.26%  |  Jtest= 1.6012 acc= 72.30%
# iter=560:  Jtrain= 1.1682 acc= 78.26%  |  Jtest= 1.6008 acc= 72.30%
# iter=561:  Jtrain= 1.1682 acc= 78.19%  |  Jtest= 1.6007 acc= 72.30%
# iter=562:  Jtrain= 1.1682 acc= 78.15%  |  Jtest= 1.6008 acc= 72.30%
# iter=563:  Jtrain= 1.1682 acc= 78.19%  |  Jtest= 1.6011 acc= 72.30%
# iter=564:  Jtrain= 1.1681 acc= 78.22%  |  Jtest= 1.6009 acc= 72.30%
# iter=565:  Jtrain= 1.1679 acc= 78.04%  |  Jtest= 1.6019 acc= 72.30%
# iter=566:  Jtrain= 1.1676 acc= 77.78%  |  Jtest= 1.6057 acc= 71.26%
# iter=567:  Jtrain= 1.1657 acc= 78.11%  |  Jtest= 1.6135 acc= 72.00%
# iter=568:  Jtrain= 1.1657 acc= 78.00%  |  Jtest= 1.6139 acc= 71.85%
# iter=569:  Jtrain= 1.1656 acc= 78.04%  |  Jtest= 1.6128 acc= 72.00%
# iter=570:  Jtrain= 1.1656 acc= 78.00%  |  Jtest= 1.6127 acc= 72.00%
# iter=571:  Jtrain= 1.1655 acc= 77.96%  |  Jtest= 1.6134 acc= 71.85%
# iter=572:  Jtrain= 1.1655 acc= 78.00%  |  Jtest= 1.6134 acc= 71.85%
# iter=573:  Jtrain= 1.1655 acc= 78.04%  |  Jtest= 1.6137 acc= 71.85%
# iter=574:  Jtrain= 1.1653 acc= 77.96%  |  Jtest= 1.6126 acc= 71.85%
# iter=575:  Jtrain= 1.1651 acc= 78.07%  |  Jtest= 1.6109 acc= 72.15%
# iter=576:  Jtrain= 1.1644 acc= 78.22%  |  Jtest= 1.6101 acc= 72.44%
# iter=577:  Jtrain= 1.1640 acc= 78.30%  |  Jtest= 1.6112 acc= 72.15%
# iter=578:  Jtrain= 1.1639 acc= 78.11%  |  Jtest= 1.6106 acc= 71.85%
# iter=579:  Jtrain= 1.1638 acc= 78.19%  |  Jtest= 1.6093 acc= 72.00%
# iter=580:  Jtrain= 1.1637 acc= 78.15%  |  Jtest= 1.6089 acc= 72.15%
# iter=581:  Jtrain= 1.1637 acc= 78.30%  |  Jtest= 1.6085 acc= 72.00%
# iter=582:  Jtrain= 1.1636 acc= 78.07%  |  Jtest= 1.6082 acc= 72.00%
# iter=583:  Jtrain= 1.1636 acc= 78.15%  |  Jtest= 1.6090 acc= 71.85%
# iter=584:  Jtrain= 1.1636 acc= 78.19%  |  Jtest= 1.6088 acc= 72.00%
# iter=585:  Jtrain= 1.1635 acc= 78.22%  |  Jtest= 1.6098 acc= 71.85%
# iter=586:  Jtrain= 1.1633 acc= 78.30%  |  Jtest= 1.6108 acc= 71.85%
# iter=587:  Jtrain= 1.1629 acc= 78.19%  |  Jtest= 1.6095 acc= 72.15%
# iter=588:  Jtrain= 1.1629 acc= 78.33%  |  Jtest= 1.6094 acc= 72.00%
# iter=589:  Jtrain= 1.1628 acc= 78.37%  |  Jtest= 1.6095 acc= 72.30%
# iter=590:  Jtrain= 1.1628 acc= 78.37%  |  Jtest= 1.6094 acc= 72.15%
# iter=591:  Jtrain= 1.1628 acc= 78.26%  |  Jtest= 1.6094 acc= 71.85%
# iter=592:  Jtrain= 1.1628 acc= 78.37%  |  Jtest= 1.6097 acc= 72.15%
# iter=593:  Jtrain= 1.1626 acc= 78.56%  |  Jtest= 1.6092 acc= 72.30%
# iter=594:  Jtrain= 1.1625 acc= 78.44%  |  Jtest= 1.6085 acc= 72.30%
# iter=595:  Jtrain= 1.1625 acc= 78.37%  |  Jtest= 1.6086 acc= 72.30%
# iter=596:  Jtrain= 1.1625 acc= 78.48%  |  Jtest= 1.6086 acc= 72.15%
# iter=597:  Jtrain= 1.1625 acc= 78.44%  |  Jtest= 1.6083 acc= 72.30%
# iter=598:  Jtrain= 1.1625 acc= 78.30%  |  Jtest= 1.6082 acc= 72.30%
# iter=599:  Jtrain= 1.1624 acc= 78.48%  |  Jtest= 1.6084 acc= 72.00%
# iter=600:  Jtrain= 1.1622 acc= 78.74%  |  Jtest= 1.6079 acc= 72.15%
#          Current function value: 1.162171
#          Iterations: 600
#          Function evaluations: 1115
#          Gradient evaluations: 1115
# accuracy on training set = 0.7181481481481482
# accuracy on test set = 0.7437037037037038
# Colab CPU performance
# CPU times: user 6min 53s, sys: 1min 47s, total: 8min 40s
# Wall time: 6min 54s
# /usr/local/lib/python3.10/dist-packages/scipy/optimize/_optimize.py:1698: OptimizeWarning: Maximum number of iterations has been exceeded.
#   res = _minimize_cg(f, x0, args, fprime, callback=callback, **opts)
